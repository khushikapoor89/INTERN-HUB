# %%
def to_do_list():
    tasks = []

    while True:
        print("\n----> To-Do List <----")
        print("1. Add Task")
        print("2. View Tasks")
        print("3. Mark Task as Done")
        print("4. Exit")

        choice = input("which one do you like to enter: ")

        if choice == '1':
            print()
            n_tasks = int(input("How many task you want to add? : "))
            
            for i in range(n_tasks):
                task = input("Enter the task: ")
                tasks.append({"task": task, "done": False})
                print("Your Task is added!")

        elif choice == '2':
            print("\nTasks:")
            for i, task in enumerate(tasks, 1):
                status = "Done" if task["done"] else "Not Done"
                print(f"{i}. {task['task']} ({status})")
        elif choice == '3':
            task_index = int(input("Enter the task number to mark as done: ")) - 1
            if 0 <= task_index < len(tasks):
                tasks[task_index]["done"] = True
                print("Task marked as done!")
            else:
                print("Invalid task number.")

        elif choice == '4':
            print("Have a nice day buddy.")
            break

        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    to_do_list()
# Out:
# ----> To-Do List <----
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Done
# 4. Exit
# which one do you like to enter: 1
#
# How many task you want to add? : 1
# Enter the task: wake up
# Your Task is added!
#
# ----> To-Do List <----
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Done
# 4. Exit
# which one do you like to enter: 3
# Enter the task number to mark as done: 1
# Task marked as done!
#
# ----> To-Do List <----
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Done
# 4. Exit
# which one do you like to enter: 2
#
# Tasks:
# 1. wake up (Done)
#
# ----> To-Do List <----
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Done
# 4. Exit
# which one do you like to enter: 4
# Have a nice day buddy.
